# %% [markdown]
# ### Database works.
# In this **notebook** we have a lot of good stuff:
# * Connecting to a database
# * Creating schema, table
# * Renaming files
# * Import raster data to this table
# * Organize the table, addi

# %%
# %load_ext sql
import os, getpass, time
import xuleta as xu

# %%
user = input("Username: ")
password = getpass.getpass('Enter your password: ')
database = input("Database: ")
connection_string = "postgresql://%s:%s@localhost/%s" %(user,password,database)
# %sql $connection_string
# Out:
# Username: denis
# Enter your password: ········
# Database: drought
# 'Connected: denis@drought'

# %% [markdown]
# #### Renaming files using xuleta

# %%
folder = "/media/denis/seagate/MODIS/R_MYD17A2H/h11v04/Gross_PP_8Days_500m_v6/GPP"
xu.renamedate(folder=folder,oldf="%Y_%j",newf="%Y-%m-%d",wts=14)

# %% [markdown]
# ---
#
# ---
# ## Creating Schemas, tables
# **Working on MODIS TILE h11v04 Variable GPP**

# %%
# %sql CREATE SCHEMA modis11v04;

# %%
# %%time
# %%sql CREATE TABLE modis11v04.gpp(
        rid serial NOT NULL,
        rast raster,
        filename text,
        acquisition_range daterange,
        CONSTRAINT modis11v04_gpp_pkey
        PRIMARY KEY (rid));
        CREATE INDEX modis11v04_gpp_wkb_rast_idx
        ON modis11v04.gpp
        USING GIST (ST_ConvexHull(rast));
        COMMENT ON TABLE modis11v04.gpp
        IS 'Table that stores values of GPP - 8day for tile h11v04.';

# %% [markdown]
# ### Importing images to the database
# Make sure the schema.table matches the images I'm importing.
#
# You can watch the verbose in the terminal to make sure that things are going ok.

# %%
imfolder = "/media/denis/seagate/MODIS/R_MYD17A2H/h11v04/Gross_PP_8Days_500m_v6/GPP/"

t0 = time.time()
os.system("raster2pgsql -a -C -F -M -s 4326 -t 200x200 -N 32767 "+imfolder+
#change the schema.table
          "*.tif modis11v04.gpp | psql -p 5432 -d drought -U denis")

taime = time.time() - t0
xu.shemale(taime/60)

# %% [markdown]
# You can confirm that the raster was properly loaded with all its attributes by looking at the raster_columns view, which stores raster metadata (here, you only retrieve the table’s schema, name, SRID and NoData value, but it is a good practice to examine all information stored in this view)

# %%
# %%time
# %%sql SELECT
    r_table_schema AS schema,
    r_table_name AS table,
    srid,
    nodata_values AS nodata
    FROM raster_columns
    WHERE r_table_name = 'modis11v04.gpp';

# %%
#%lsmagic

# %% [markdown]
# In the case of more complex filenames with a variable number of characters, you could still retrieve the encoded date using the substring function, by extracting the relevant characters relative to some other characters found first using the position function. Let us now update the table by converting the filenames into the date ranges according to the convention used in file naming (note that there is an
# additional constraint that selects 1 January when the start date ? 16 days exceeds the beginning of the year):
# ### atente para o 8 ou 16 dias

# %%
# %%time
# %%sql    UPDATE modis11v04.gpp
    SET acquisition_range = daterange(
    (substring(filename FROM 1 FOR 4) || '-' ||
    substring(filename FROM 6 FOR 2) || '-' ||
    substring(filename FROM 9 FOR 2))::date,
    LEAST((substring(filename FROM 1 FOR 4) || '-' ||
    substring(filename FROM 6 FOR 2) || '-' ||
    substring(filename FROM 9 FOR 2))::date + 8,
    (substring(filename FROM 1 FOR 4)::integer + 1
    || '-' || '01' || '-' || '01')::date));

# %% [markdown]
# As for any type of column, if the table contains a large number of rows
# (e.g. [10,000), querying based on the acquisition_range will be faster if you first index it (you can do it even if the table is not that big, as the PostgreSQL planner will determine whether the query will be faster by using the index or not):

# %%
# %%time
# %%sql     CREATE INDEX gpp_acquisition_range_idx
    ON modis11v04.gpp (acquisition_range);

# %% [markdown]
# Now, each tile (and therefore each pixel) has a spatial and a temporal component and thus can be queried according to both criteria. For instance, these are the 10 first tiles corresponding to 1 March 2008, using the ‘@[’ operator (‘contains’). Note that this is a leap year so that the corresponding period ends on 5 March:

# %%
# %%time
# %%sql     SELECT rid, filename, acquisition_range
    FROM modis11v04.gpp
    WHERE acquisition_range @> '2015-12-01'::date
    LIMIT 5;

# %% [markdown]
# ** Retrieving time-series from a given point**
#
# using this query, we can get the time-series for a point, e.g. -110.868,45.050. It's super fast!

# %%
# %%time
# %%sql SELECT 
        rid, 
        acquisition_range,
        ST_Value(rast, ST_SetSRID(ST_MakePoint(-92.891,42.436), 4326)) AS gpp
    FROM modis11v04.gpp
         WHERE ST_Intersects(ST_SetSRID(ST_MakePoint(-92.891,42.436), 4326), rast)
           AND acquisition_range && '[2002-01-01,2016-12-31]'::daterange
    ORDER BY acquisition_range;
# Out:
# 660 rows affected.
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 675 ms
# [(290, DateRange(datetime.date(2002, 7, 28), datetime.date(2002, 8, 5), '[)'), 517.0),
#  (698, DateRange(datetime.date(2002, 8, 5), datetime.date(2002, 8, 13), '[)'), 434.0),
#  (1106, DateRange(datetime.date(2002, 8, 13), datetime.date(2002, 8, 21), '[)'), 593.0),
#  (1514, DateRange(datetime.date(2002, 8, 21), datetime.date(2002, 8, 29), '[)'), 542.0),
#  (1922, DateRange(datetime.date(2002, 8, 29), datetime.date(2002, 9, 6), '[)'), 450.0),
#  (2330, DateRange(datetime.date(2002, 9, 6), datetime.date(2002, 9, 14), '[)'), 365.0),
#  (2738, DateRange(datetime.date(2002, 9, 14), datetime.date(2002, 9, 22), '[)'), 300.0),
#  (3146, DateRange(datetime.date(2002, 9, 22), datetime.date(2002, 9, 30), '[)'), 259.0),
#  (3554, DateRange(datetime.date(2002, 9, 30), datetime.date(2002, 10, 8), '[)'), 78.0),
#  (3962, DateRange(datetime.date(2002, 10, 8), datetime.date(2002, 10, 16), '[)'), 108.0),
#  (4370, DateRange(datetime.date(2002, 10, 16), datetime.date(2002, 10, 24), '[)'), 44.0),
#  (4778, DateRange(datetime.date(2002, 10, 24), datetime.date(2002, 11, 1), '[)'), 9.0),
#  (5186, DateRange(datetime.date(2002, 11, 1), datetime.date(2002, 11, 9), '[)'), 15.0),
#  (5594, DateRange(datetime.date(2002, 11, 9), datetime.date(2002, 11, 17), '[)'), 20.0),
#  (6002, DateRange(datetime.date(2002, 11, 17), datetime.date(2002, 11, 25), '[)'), 17.0),
#  (6410, DateRange(datetime.date(2002, 11, 25), datetime.date(2002, 12, 3), '[)'), 4.0),
#  (6818, DateRange(datetime.date(2002, 12, 3), datetime.date(2002, 12, 11), '[)'), 2.0),
#  (7226, DateRange(datetime.date(2002, 12, 11), datetime.date(2002, 12, 19), '[)'), 7.0),
#  (7634, DateRange(datetime.date(2002, 12, 19), datetime.date(2002, 12, 27), '[)'), 2.0),
#  (8042, DateRange(datetime.date(2002, 12, 27), datetime.date(2003, 1, 1), '[)'), 7.0),
#  (8450, DateRange(datetime.date(2003, 1, 1), datetime.date(2003, 1, 9), '[)'), 6.0),
#  (8858, DateRange(datetime.date(2003, 1, 9), datetime.date(2003, 1, 17), '[)'), 2.0),
#  (9266, DateRange(datetime.date(2003, 1, 17), datetime.date(2003, 1, 25), '[)'), 0.0),
#  (9674, DateRange(datetime.date(2003, 1, 25), datetime.date(2003, 2, 2), '[)'), 2.0),
#  (10082, DateRange(datetime.date(2003, 2, 2), datetime.date(2003, 2, 10), '[)'), 0.0),
#  (10490, DateRange(datetime.date(2003, 2, 10), datetime.date(2003, 2, 18), '[)'), 0.0),
#  (10898, DateRange(datetime.date(2003, 2, 18), datetime.date(2003, 2, 26), '[)'), 4.0),
#  (11306, DateRange(datetime.date(2003, 2, 26), datetime.date(2003, 3, 6), '[)'), 2.0),
#  (11714, DateRange(datetime.date(2003, 3, 6), datetime.date(2003, 3, 14), '[)'), 11.0),
#  (12122, DateRange(datetime.date(2003, 3, 14), datetime.date(2003, 3, 22), '[)'), 38.0),
#  (12530, DateRange(datetime.date(2003, 3, 22), datetime.date(2003, 3, 30), '[)'), 28.0),
#  (12938, DateRange(datetime.date(2003, 3, 30), datetime.date(2003, 4, 7), '[)'), 32.0),
#  (13346, DateRange(datetime.date(2003, 4, 7), datetime.date(2003, 4, 15), '[)'), 41.0),
#  (13754, DateRange(datetime.date(2003, 4, 15), datetime.date(2003, 4, 23), '[)'), 63.0),
#  (14162, DateRange(datetime.date(2003, 4, 23), datetime.date(2003, 5, 1), '[)'), 130.0),
#  (14570, DateRange(datetime.date(2003, 5, 1), datetime.date(2003, 5, 9), '[)'), 142.0),
#  (14978, DateRange(datetime.date(2003, 5, 9), datetime.date(2003, 5, 17), '[)'), 179.0),
#  (15386, DateRange(datetime.date(2003, 5, 17), datetime.date(2003, 5, 25), '[)'), 194.0),
#  (15794, DateRange(datetime.date(2003, 5, 25), datetime.date(2003, 6, 2), '[)'), 238.0),
#  (16202, DateRange(datetime.date(2003, 6, 2), datetime.date(2003, 6, 10), '[)'), 185.0),
#  (16610, DateRange(datetime.date(2003, 6, 10), datetime.date(2003, 6, 18), '[)'), 334.0),
#  (17018, DateRange(datetime.date(2003, 6, 18), datetime.date(2003, 6, 26), '[)'), 358.0),
#  (17426, DateRange(datetime.date(2003, 6, 26), datetime.date(2003, 7, 4), '[)'), 513.0),
#  (17834, DateRange(datetime.date(2003, 7, 4), datetime.date(2003, 7, 12), '[)'), 533.0),
#  (18242, DateRange(datetime.date(2003, 7, 12), datetime.date(2003, 7, 20), '[)'), 605.0),
#  (18650, DateRange(datetime.date(2003, 7, 20), datetime.date(2003, 7, 28), '[)'), 542.0),
#  (19058, DateRange(datetime.date(2003, 7, 28), datetime.date(2003, 8, 5), '[)'), 465.0),
#  (19466, DateRange(datetime.date(2003, 8, 5), datetime.date(2003, 8, 13), '[)'), 484.0),
#  (19874, DateRange(datetime.date(2003, 8, 13), datetime.date(2003, 8, 21), '[)'), 380.0),
#  (20282, DateRange(datetime.date(2003, 8, 21), datetime.date(2003, 8, 29), '[)'), 263.0),
#  (20690, DateRange(datetime.date(2003, 8, 29), datetime.date(2003, 9, 6), '[)'), 393.0),
#  (21098, DateRange(datetime.date(2003, 9, 6), datetime.date(2003, 9, 14), '[)'), 281.0),
#  (21506, DateRange(datetime.date(2003, 9, 14), datetime.date(2003, 9, 22), '[)'), 250.0),
#  (21914, DateRange(datetime.date(2003, 9, 22), datetime.date(2003, 9, 30), '[)'), 195.0),
#  (22322, DateRange(datetime.date(2003, 9, 30), datetime.date(2003, 10, 8), '[)'), 110.0),
#  (22730, DateRange(datetime.date(2003, 10, 8), datetime.date(2003, 10, 16), '[)'), 116.0),
#  (23138, DateRange(datetime.date(2003, 10, 16), datetime.date(2003, 10, 24), '[)'), 96.0),
#  (23546, DateRange(datetime.date(2003, 10, 24), datetime.date(2003, 11, 1), '[)'), 32.0),
#  (23954, DateRange(datetime.date(2003, 11, 1), datetime.date(2003, 11, 9), '[)'), 12.0),
#  (24362, DateRange(datetime.date(2003, 11, 9), datetime.date(2003, 11, 17), '[)'), 11.0),
#  (24770, DateRange(datetime.date(2003, 11, 17), datetime.date(2003, 11, 25), '[)'), 21.0),
#  (25178, DateRange(datetime.date(2003, 11, 25), datetime.date(2003, 12, 3), '[)'), 6.0),
#  (25586, DateRange(datetime.date(2003, 12, 3), datetime.date(2003, 12, 11), '[)'), 0.0),
#  (25994, DateRange(datetime.date(2003, 12, 11), datetime.date(2003, 12, 19), '[)'), 0.0),
#  (26402, DateRange(datetime.date(2003, 12, 19), datetime.date(2003, 12, 27), '[)'), 3.0),
#  (26810, DateRange(datetime.date(2003, 12, 27), datetime.date(2004, 1, 1), '[)'), 2.0),
#  (27218, DateRange(datetime.date(2004, 1, 1), datetime.date(2004, 1, 9), '[)'), 0.0),
#  (27626, DateRange(datetime.date(2004, 1, 9), datetime.date(2004, 1, 17), '[)'), 5.0),
#  (28034, DateRange(datetime.date(2004, 1, 17), datetime.date(2004, 1, 25), '[)'), 1.0),
#  (28442, DateRange(datetime.date(2004, 1, 25), datetime.date(2004, 2, 2), '[)'), 0.0),
#  (28850, DateRange(datetime.date(2004, 2, 2), datetime.date(2004, 2, 10), '[)'), 0.0),
#  (29258, DateRange(datetime.date(2004, 2, 10), datetime.date(2004, 2, 18), '[)'), 0.0),
#  (29666, DateRange(datetime.date(2004, 2, 18), datetime.date(2004, 2, 26), '[)'), 0.0),
#  (30074, DateRange(datetime.date(2004, 2, 26), datetime.date(2004, 3, 5), '[)'), 10.0),
#  (30482, DateRange(datetime.date(2004, 3, 5), datetime.date(2004, 3, 13), '[)'), 12.0),
#  (30890, DateRange(datetime.date(2004, 3, 13), datetime.date(2004, 3, 21), '[)'), 30.0),
#  (31298, DateRange(datetime.date(2004, 3, 21), datetime.date(2004, 3, 29), '[)'), 42.0),
#  (31706, DateRange(datetime.date(2004, 3, 29), datetime.date(2004, 4, 6), '[)'), 54.0),
#  (32114, DateRange(datetime.date(2004, 4, 6), datetime.date(2004, 4, 14), '[)'), 75.0),
#  (32522, DateRange(datetime.date(2004, 4, 14), datetime.date(2004, 4, 22), '[)'), 103.0),
#  (32930, DateRange(datetime.date(2004, 4, 22), datetime.date(2004, 4, 30), '[)'), 107.0),
#  (33338, DateRange(datetime.date(2004, 4, 30), datetime.date(2004, 5, 8), '[)'), 146.0),
#  (33746, DateRange(datetime.date(2004, 5, 8), datetime.date(2004, 5, 16), '[)'), 156.0),
#  (34154, DateRange(datetime.date(2004, 5, 16), datetime.date(2004, 5, 24), '[)'), 188.0),
#  (34562, DateRange(datetime.date(2004, 5, 24), datetime.date(2004, 6, 1), '[)'), 270.0),
#  (34970, DateRange(datetime.date(2004, 6, 1), datetime.date(2004, 6, 9), '[)'), 251.0),
#  (35378, DateRange(datetime.date(2004, 6, 9), datetime.date(2004, 6, 17), '[)'), 297.0),
#  (35786, DateRange(datetime.date(2004, 6, 17), datetime.date(2004, 6, 25), '[)'), 389.0),
#  (36194, DateRange(datetime.date(2004, 6, 25), datetime.date(2004, 7, 3), '[)'), 421.0),
#  (36602, DateRange(datetime.date(2004, 7, 3), datetime.date(2004, 7, 11), '[)'), 425.0),
#  (37010, DateRange(datetime.date(2004, 7, 11), datetime.date(2004, 7, 19), '[)'), 736.0),
#  (37418, DateRange(datetime.date(2004, 7, 19), datetime.date(2004, 7, 27), '[)'), 554.0),
#  (37826, DateRange(datetime.date(2004, 7, 27), datetime.date(2004, 8, 4), '[)'), 740.0),
#  (38234, DateRange(datetime.date(2004, 8, 4), datetime.date(2004, 8, 12), '[)'), 391.0),
#  (38642, DateRange(datetime.date(2004, 8, 12), datetime.date(2004, 8, 20), '[)'), 643.0),
#  (39050, DateRange(datetime.date(2004, 8, 20), datetime.date(2004, 8, 28), '[)'), 585.0),
#  (39458, DateRange(datetime.date(2004, 8, 28), datetime.date(2004, 9, 5), '[)'), 654.0),
#  (39866, DateRange(datetime.date(2004, 9, 5), datetime.date(2004, 9, 13), '[)'), 554.0),
#  (40274, DateRange(datetime.date(2004, 9, 13), datetime.date(2004, 9, 21), '[)'), 421.0),
#  (40682, DateRange(datetime.date(2004, 9, 21), datetime.date(2004, 9, 29), '[)'), 278.0),
#  (41090, DateRange(datetime.date(2004, 9, 29), datetime.date(2004, 10, 7), '[)'), 113.0),
#  (41498, DateRange(datetime.date(2004, 10, 7), datetime.date(2004, 10, 15), '[)'), 101.0),
#  (41906, DateRange(datetime.date(2004, 10, 15), datetime.date(2004, 10, 23), '[)'), 45.0),
#  (42314, DateRange(datetime.date(2004, 10, 23), datetime.date(2004, 10, 31), '[)'), 79.0),
#  (42722, DateRange(datetime.date(2004, 10, 31), datetime.date(2004, 11, 8), '[)'), 37.0),
#  (43130, DateRange(datetime.date(2004, 11, 8), datetime.date(2004, 11, 16), '[)'), 32.0),
#  (43538, DateRange(datetime.date(2004, 11, 16), datetime.date(2004, 11, 24), '[)'), 13.0),
#  (43946, DateRange(datetime.date(2004, 11, 24), datetime.date(2004, 12, 2), '[)'), 10.0),
#  (44354, DateRange(datetime.date(2004, 12, 2), datetime.date(2004, 12, 10), '[)'), 13.0),
#  (44762, DateRange(datetime.date(2004, 12, 10), datetime.date(2004, 12, 18), '[)'), 6.0),
#  (45170, DateRange(datetime.date(2004, 12, 18), datetime.date(2004, 12, 26), '[)'), 1.0),
#  (45578, DateRange(datetime.date(2004, 12, 26), datetime.date(2005, 1, 1), '[)'), 1.0),
#  (45986, DateRange(datetime.date(2005, 1, 1), datetime.date(2005, 1, 9), '[)'), 0.0),
#  (46394, DateRange(datetime.date(2005, 1, 9), datetime.date(2005, 1, 17), '[)'), 0.0),
#  (46802, DateRange(datetime.date(2005, 1, 17), datetime.date(2005, 1, 25), '[)'), 0.0),
#  (47210, DateRange(datetime.date(2005, 1, 25), datetime.date(2005, 2, 2), '[)'), 0.0),
#  (47618, DateRange(datetime.date(2005, 2, 2), datetime.date(2005, 2, 10), '[)'), 6.0),
#  (48026, DateRange(datetime.date(2005, 2, 10), datetime.date(2005, 2, 18), '[)'), 5.0),
#  (48434, DateRange(datetime.date(2005, 2, 18), datetime.date(2005, 2, 26), '[)'), 4.0),
#  (48842, DateRange(datetime.date(2005, 2, 26), datetime.date(2005, 3, 6), '[)'), 6.0),
#  (49250, DateRange(datetime.date(2005, 3, 6), datetime.date(2005, 3, 14), '[)'), 15.0),
#  (49658, DateRange(datetime.date(2005, 3, 14), datetime.date(2005, 3, 22), '[)'), 8.0),
#  (50066, DateRange(datetime.date(2005, 3, 22), datetime.date(2005, 3, 30), '[)'), 18.0),
#  (50474, DateRange(datetime.date(2005, 3, 30), datetime.date(2005, 4, 7), '[)'), 70.0),
#  (50882, DateRange(datetime.date(2005, 4, 7), datetime.date(2005, 4, 15), '[)'), 124.0),
#  (51290, DateRange(datetime.date(2005, 4, 15), datetime.date(2005, 4, 23), '[)'), 118.0),
#  (51698, DateRange(datetime.date(2005, 4, 23), datetime.date(2005, 5, 1), '[)'), 88.0),
#  (52106, DateRange(datetime.date(2005, 5, 1), datetime.date(2005, 5, 9), '[)'), 129.0),
#  (52514, DateRange(datetime.date(2005, 5, 9), datetime.date(2005, 5, 17), '[)'), 176.0),
#  (52922, DateRange(datetime.date(2005, 5, 17), datetime.date(2005, 5, 25), '[)'), 252.0),
#  (53330, DateRange(datetime.date(2005, 5, 25), datetime.date(2005, 6, 2), '[)'), 207.0),
#  (53738, DateRange(datetime.date(2005, 6, 2), datetime.date(2005, 6, 10), '[)'), 203.0),
#  (54146, DateRange(datetime.date(2005, 6, 10), datetime.date(2005, 6, 18), '[)'), 357.0),
#  (54554, DateRange(datetime.date(2005, 6, 18), datetime.date(2005, 6, 26), '[)'), 394.0),
#  (54962, DateRange(datetime.date(2005, 6, 26), datetime.date(2005, 7, 4), '[)'), 636.0),
#  (55370, DateRange(datetime.date(2005, 7, 4), datetime.date(2005, 7, 12), '[)'), 707.0),
#  (55778, DateRange(datetime.date(2005, 7, 12), datetime.date(2005, 7, 20), '[)'), 668.0),
#  (56186, DateRange(datetime.date(2005, 7, 20), datetime.date(2005, 7, 28), '[)'), 532.0),
#  (56594, DateRange(datetime.date(2005, 7, 28), datetime.date(2005, 8, 5), '[)'), 557.0),
#  (57002, DateRange(datetime.date(2005, 8, 5), datetime.date(2005, 8, 13), '[)'), 542.0),
#  (57410, DateRange(datetime.date(2005, 8, 13), datetime.date(2005, 8, 21), '[)'), 552.0),
#  (57818, DateRange(datetime.date(2005, 8, 21), datetime.date(2005, 8, 29), '[)'), 466.0),
#  (58226, DateRange(datetime.date(2005, 8, 29), datetime.date(2005, 9, 6), '[)'), 441.0),
#  (58634, DateRange(datetime.date(2005, 9, 6), datetime.date(2005, 9, 14), '[)'), 281.0),
#  (59042, DateRange(datetime.date(2005, 9, 14), datetime.date(2005, 9, 22), '[)'), 271.0),
#  (59450, DateRange(datetime.date(2005, 9, 22), datetime.date(2005, 9, 30), '[)'), 126.0),
#  (59858, DateRange(datetime.date(2005, 9, 30), datetime.date(2005, 10, 8), '[)'), 115.0),
#  (60266, DateRange(datetime.date(2005, 10, 8), datetime.date(2005, 10, 16), '[)'), 110.0),
#  (60674, DateRange(datetime.date(2005, 10, 16), datetime.date(2005, 10, 24), '[)'), 80.0),
#  (61082, DateRange(datetime.date(2005, 10, 24), datetime.date(2005, 11, 1), '[)'), 53.0),
#  (61490, DateRange(datetime.date(2005, 11, 1), datetime.date(2005, 11, 9), '[)'), 47.0),
#  (61898, DateRange(datetime.date(2005, 11, 9), datetime.date(2005, 11, 17), '[)'), 27.0),
#  (62306, DateRange(datetime.date(2005, 11, 17), datetime.date(2005, 11, 25), '[)'), 13.0),
#  (62714, DateRange(datetime.date(2005, 11, 25), datetime.date(2005, 12, 3), '[)'), 3.0),
#  (63122, DateRange(datetime.date(2005, 12, 3), datetime.date(2005, 12, 11), '[)'), 0.0),
#  (63530, DateRange(datetime.date(2005, 12, 11), datetime.date(2005, 12, 19), '[)'), 0.0),
#  (63938, DateRange(datetime.date(2005, 12, 19), datetime.date(2005, 12, 27), '[)'), 0.0),
#  (64346, DateRange(datetime.date(2005, 12, 27), datetime.date(2006, 1, 1), '[)'), 0.0),
#  (64754, DateRange(datetime.date(2006, 1, 1), datetime.date(2006, 1, 9), '[)'), 0.0),
#  (65162, DateRange(datetime.date(2006, 1, 9), datetime.date(2006, 1, 17), '[)'), 6.0),
#  (65570, DateRange(datetime.date(2006, 1, 17), datetime.date(2006, 1, 25), '[)'), 3.0),
#  (65978, DateRange(datetime.date(2006, 1, 25), datetime.date(2006, 2, 2), '[)'), 9.0),
#  (66386, DateRange(datetime.date(2006, 2, 2), datetime.date(2006, 2, 10), '[)'), 3.0),
#  (66794, DateRange(datetime.date(2006, 2, 10), datetime.date(2006, 2, 18), '[)'), 2.0),
#  (67202, DateRange(datetime.date(2006, 2, 18), datetime.date(2006, 2, 26), '[)'), 4.0),
#  (67610, DateRange(datetime.date(2006, 2, 26), datetime.date(2006, 3, 6), '[)'), 10.0),
#  (68018, DateRange(datetime.date(2006, 3, 6), datetime.date(2006, 3, 14), '[)'), 11.0),
#  (68426, DateRange(datetime.date(2006, 3, 14), datetime.date(2006, 3, 22), '[)'), 7.0),
#  (68834, DateRange(datetime.date(2006, 3, 22), datetime.date(2006, 3, 30), '[)'), 15.0),
#  (69242, DateRange(datetime.date(2006, 3, 30), datetime.date(2006, 4, 7), '[)'), 36.0),
#  (69650, DateRange(datetime.date(2006, 4, 7), datetime.date(2006, 4, 15), '[)'), 83.0),
#  (70058, DateRange(datetime.date(2006, 4, 15), datetime.date(2006, 4, 23), '[)'), 87.0),
#  (70466, DateRange(datetime.date(2006, 4, 23), datetime.date(2006, 5, 1), '[)'), 84.0),
#  (70874, DateRange(datetime.date(2006, 5, 1), datetime.date(2006, 5, 9), '[)'), 124.0),
#  (71282, DateRange(datetime.date(2006, 5, 9), datetime.date(2006, 5, 17), '[)'), 74.0),
#  (71690, DateRange(datetime.date(2006, 5, 17), datetime.date(2006, 5, 25), '[)'), 153.0),
#  (72098, DateRange(datetime.date(2006, 5, 25), datetime.date(2006, 6, 2), '[)'), 197.0),
#  (72506, DateRange(datetime.date(2006, 6, 2), datetime.date(2006, 6, 10), '[)'), 199.0),
#  (72914, DateRange(datetime.date(2006, 6, 10), datetime.date(2006, 6, 18), '[)'), 289.0),
#  (73322, DateRange(datetime.date(2006, 6, 18), datetime.date(2006, 6, 26), '[)'), 299.0),
#  (73730, DateRange(datetime.date(2006, 6, 26), datetime.date(2006, 7, 4), '[)'), 433.0),
#  (74138, DateRange(datetime.date(2006, 7, 4), datetime.date(2006, 7, 12), '[)'), 426.0),
#  (74546, DateRange(datetime.date(2006, 7, 12), datetime.date(2006, 7, 20), '[)'), 577.0),
#  (74954, DateRange(datetime.date(2006, 7, 20), datetime.date(2006, 7, 28), '[)'), 519.0),
#  (75362, DateRange(datetime.date(2006, 7, 28), datetime.date(2006, 8, 5), '[)'), 388.0),
#  (75770, DateRange(datetime.date(2006, 8, 5), datetime.date(2006, 8, 13), '[)'), 470.0),
#  (76178, DateRange(datetime.date(2006, 8, 13), datetime.date(2006, 8, 21), '[)'), 512.0),
#  (76586, DateRange(datetime.date(2006, 8, 21), datetime.date(2006, 8, 29), '[)'), 454.0),
#  (76994, DateRange(datetime.date(2006, 8, 29), datetime.date(2006, 9, 6), '[)'), 501.0),
#  (77402, DateRange(datetime.date(2006, 9, 6), datetime.date(2006, 9, 14), '[)'), 338.0),
#  (77810, DateRange(datetime.date(2006, 9, 14), datetime.date(2006, 9, 22), '[)'), 299.0),
#  (78218, DateRange(datetime.date(2006, 9, 22), datetime.date(2006, 9, 30), '[)'), 217.0),
#  (78626, DateRange(datetime.date(2006, 9, 30), datetime.date(2006, 10, 8), '[)'), 130.0),
#  (79034, DateRange(datetime.date(2006, 10, 8), datetime.date(2006, 10, 16), '[)'), 67.0),
#  (79442, DateRange(datetime.date(2006, 10, 16), datetime.date(2006, 10, 24), '[)'), 32.0),
#  (79850, DateRange(datetime.date(2006, 10, 24), datetime.date(2006, 11, 1), '[)'), 37.0),
#  (80258, DateRange(datetime.date(2006, 11, 1), datetime.date(2006, 11, 9), '[)'), 24.0),
#  (80666, DateRange(datetime.date(2006, 11, 9), datetime.date(2006, 11, 17), '[)'), 11.0),
#  (81074, DateRange(datetime.date(2006, 11, 17), datetime.date(2006, 11, 25), '[)'), 13.0),
#  (81482, DateRange(datetime.date(2006, 11, 25), datetime.date(2006, 12, 3), '[)'), 6.0),
#  (81890, DateRange(datetime.date(2006, 12, 3), datetime.date(2006, 12, 11), '[)'), 3.0),
#  (82298, DateRange(datetime.date(2006, 12, 11), datetime.date(2006, 12, 19), '[)'), 8.0),
#  (82706, DateRange(datetime.date(2006, 12, 19), datetime.date(2006, 12, 27), '[)'), 6.0),
#  (83114, DateRange(datetime.date(2006, 12, 27), datetime.date(2007, 1, 1), '[)'), 3.0),
#  (83522, DateRange(datetime.date(2007, 1, 1), datetime.date(2007, 1, 9), '[)'), 7.0),
#  (83930, DateRange(datetime.date(2007, 1, 9), datetime.date(2007, 1, 17), '[)'), 1.0),
#  (84338, DateRange(datetime.date(2007, 1, 17), datetime.date(2007, 1, 25), '[)'), 0.0),
#  (84746, DateRange(datetime.date(2007, 1, 25), datetime.date(2007, 2, 2), '[)'), 0.0),
#  (85154, DateRange(datetime.date(2007, 2, 2), datetime.date(2007, 2, 10), '[)'), 0.0),
#  (85562, DateRange(datetime.date(2007, 2, 10), datetime.date(2007, 2, 18), '[)'), 0.0),
#  (85970, DateRange(datetime.date(2007, 2, 18), datetime.date(2007, 2, 26), '[)'), 5.0),
#  (86378, DateRange(datetime.date(2007, 2, 26), datetime.date(2007, 3, 6), '[)'), 0.0),
#  (86786, DateRange(datetime.date(2007, 3, 6), datetime.date(2007, 3, 14), '[)'), 10.0),
#  (87194, DateRange(datetime.date(2007, 3, 14), datetime.date(2007, 3, 22), '[)'), 31.0),
#  (87602, DateRange(datetime.date(2007, 3, 22), datetime.date(2007, 3, 30), '[)'), 30.0),
#  (88010, DateRange(datetime.date(2007, 3, 30), datetime.date(2007, 4, 7), '[)'), 28.0),
#  (88418, DateRange(datetime.date(2007, 4, 7), datetime.date(2007, 4, 15), '[)'), 25.0),
#  (88826, DateRange(datetime.date(2007, 4, 15), datetime.date(2007, 4, 23), '[)'), 94.0),
#  (89234, DateRange(datetime.date(2007, 4, 23), datetime.date(2007, 5, 1), '[)'), 146.0),
#  (89642, DateRange(datetime.date(2007, 5, 1), datetime.date(2007, 5, 9), '[)'), 101.0),
#  (90050, DateRange(datetime.date(2007, 5, 9), datetime.date(2007, 5, 17), '[)'), 213.0),
#  (90458, DateRange(datetime.date(2007, 5, 17), datetime.date(2007, 5, 25), '[)'), 192.0),
#  (90866, DateRange(datetime.date(2007, 5, 25), datetime.date(2007, 6, 2), '[)'), 194.0),
#  (91274, DateRange(datetime.date(2007, 6, 2), datetime.date(2007, 6, 10), '[)'), 309.0),
#  (91682, DateRange(datetime.date(2007, 6, 10), datetime.date(2007, 6, 18), '[)'), 416.0),
#  (92090, DateRange(datetime.date(2007, 6, 18), datetime.date(2007, 6, 26), '[)'), 430.0),
#  (92498, DateRange(datetime.date(2007, 6, 26), datetime.date(2007, 7, 4), '[)'), 632.0),
#  (92906, DateRange(datetime.date(2007, 7, 4), datetime.date(2007, 7, 12), '[)'), 599.0),
#  (93314, DateRange(datetime.date(2007, 7, 12), datetime.date(2007, 7, 20), '[)'), 652.0),
#  (93722, DateRange(datetime.date(2007, 7, 20), datetime.date(2007, 7, 28), '[)'), 713.0),
#  (94130, DateRange(datetime.date(2007, 7, 28), datetime.date(2007, 8, 5), '[)'), 544.0),
#  (94538, DateRange(datetime.date(2007, 8, 5), datetime.date(2007, 8, 13), '[)'), 599.0),
#  (94946, DateRange(datetime.date(2007, 8, 13), datetime.date(2007, 8, 21), '[)'), 459.0),
#  (95354, DateRange(datetime.date(2007, 8, 21), datetime.date(2007, 8, 29), '[)'), 536.0),
#  (95762, DateRange(datetime.date(2007, 8, 29), datetime.date(2007, 9, 6), '[)'), 569.0),
#  (96170, DateRange(datetime.date(2007, 9, 6), datetime.date(2007, 9, 14), '[)'), 460.0),
#  (96578, DateRange(datetime.date(2007, 9, 14), datetime.date(2007, 9, 22), '[)'), 245.0),
#  (96986, DateRange(datetime.date(2007, 9, 22), datetime.date(2007, 9, 30), '[)'), 189.0),
#  (97394, DateRange(datetime.date(2007, 9, 30), datetime.date(2007, 10, 8), '[)'), 95.0),
#  (97802, DateRange(datetime.date(2007, 10, 8), datetime.date(2007, 10, 16), '[)'), 115.0),
#  (98210, DateRange(datetime.date(2007, 10, 16), datetime.date(2007, 10, 24), '[)'), 32.0),
#  (98618, DateRange(datetime.date(2007, 10, 24), datetime.date(2007, 11, 1), '[)'), 77.0),
#  (99026, DateRange(datetime.date(2007, 11, 1), datetime.date(2007, 11, 9), '[)'), 25.0),
#  (99434, DateRange(datetime.date(2007, 11, 9), datetime.date(2007, 11, 17), '[)'), 22.0),
#  (99842, DateRange(datetime.date(2007, 11, 17), datetime.date(2007, 11, 25), '[)'), 13.0),
#  (100250, DateRange(datetime.date(2007, 11, 25), datetime.date(2007, 12, 3), '[)'), 2.0),
#  (100658, DateRange(datetime.date(2007, 12, 3), datetime.date(2007, 12, 11), '[)'), 0.0),
#  (101066, DateRange(datetime.date(2007, 12, 11), datetime.date(2007, 12, 19), '[)'), 0.0),
#  (101474, DateRange(datetime.date(2007, 12, 19), datetime.date(2007, 12, 27), '[)'), 0.0),
#  (101882, DateRange(datetime.date(2007, 12, 27), datetime.date(2008, 1, 1), '[)'), 0.0),
#  (102290, DateRange(datetime.date(2008, 1, 1), datetime.date(2008, 1, 9), '[)'), 0.0),
#  (102698, DateRange(datetime.date(2008, 1, 9), datetime.date(2008, 1, 17), '[)'), 0.0),
#  (103106, DateRange(datetime.date(2008, 1, 17), datetime.date(2008, 1, 25), '[)'), 0.0),
#  (103514, DateRange(datetime.date(2008, 1, 25), datetime.date(2008, 2, 2), '[)'), 0.0),
#  (103922, DateRange(datetime.date(2008, 2, 2), datetime.date(2008, 2, 10), '[)'), 0.0),
#  (104330, DateRange(datetime.date(2008, 2, 10), datetime.date(2008, 2, 18), '[)'), 0.0),
#  (104738, DateRange(datetime.date(2008, 2, 18), datetime.date(2008, 2, 26), '[)'), 0.0),
#  (105146, DateRange(datetime.date(2008, 2, 26), datetime.date(2008, 3, 5), '[)'), 0.0),
#  (105554, DateRange(datetime.date(2008, 3, 5), datetime.date(2008, 3, 13), '[)'), 0.0),
#  (105962, DateRange(datetime.date(2008, 3, 13), datetime.date(2008, 3, 21), '[)'), 15.0),
#  (106370, DateRange(datetime.date(2008, 3, 21), datetime.date(2008, 3, 29), '[)'), 12.0),
#  (106778, DateRange(datetime.date(2008, 3, 29), datetime.date(2008, 4, 6), '[)'), 27.0),
#  (107186, DateRange(datetime.date(2008, 4, 6), datetime.date(2008, 4, 14), '[)'), 27.0),
#  (107594, DateRange(datetime.date(2008, 4, 14), datetime.date(2008, 4, 22), '[)'), 60.0),
#  (108002, DateRange(datetime.date(2008, 4, 22), datetime.date(2008, 4, 30), '[)'), 75.0),
#  (108410, DateRange(datetime.date(2008, 4, 30), datetime.date(2008, 5, 8), '[)'), 103.0),
#  (108818, DateRange(datetime.date(2008, 5, 8), datetime.date(2008, 5, 16), '[)'), 137.0),
#  (109226, DateRange(datetime.date(2008, 5, 16), datetime.date(2008, 5, 24), '[)'), 96.0),
#  (109634, DateRange(datetime.date(2008, 5, 24), datetime.date(2008, 6, 1), '[)'), 102.0),
#  (110042, DateRange(datetime.date(2008, 6, 1), datetime.date(2008, 6, 9), '[)'), 192.0),
#  (110450, DateRange(datetime.date(2008, 6, 9), datetime.date(2008, 6, 17), '[)'), 249.0),
#  (110858, DateRange(datetime.date(2008, 6, 17), datetime.date(2008, 6, 25), '[)'), 282.0),
#  (111266, DateRange(datetime.date(2008, 6, 25), datetime.date(2008, 7, 3), '[)'), 353.0),
#  (111674, DateRange(datetime.date(2008, 7, 3), datetime.date(2008, 7, 11), '[)'), 515.0),
#  (112082, DateRange(datetime.date(2008, 7, 11), datetime.date(2008, 7, 19), '[)'), 540.0),
#  (112490, DateRange(datetime.date(2008, 7, 19), datetime.date(2008, 7, 27), '[)'), 492.0),
#  (112898, DateRange(datetime.date(2008, 7, 27), datetime.date(2008, 8, 4), '[)'), 651.0),
#  (113306, DateRange(datetime.date(2008, 8, 4), datetime.date(2008, 8, 12), '[)'), 694.0),
#  (113714, DateRange(datetime.date(2008, 8, 12), datetime.date(2008, 8, 20), '[)'), 696.0),
#  (114122, DateRange(datetime.date(2008, 8, 20), datetime.date(2008, 8, 28), '[)'), 702.0),
#  (114530, DateRange(datetime.date(2008, 8, 28), datetime.date(2008, 9, 5), '[)'), 675.0),
#  (114938, DateRange(datetime.date(2008, 9, 5), datetime.date(2008, 9, 13), '[)'), 241.0),
#  (115346, DateRange(datetime.date(2008, 9, 13), datetime.date(2008, 9, 21), '[)'), 472.0),
#  (115754, DateRange(datetime.date(2008, 9, 21), datetime.date(2008, 9, 29), '[)'), 339.0),
#  (116162, DateRange(datetime.date(2008, 9, 29), datetime.date(2008, 10, 7), '[)'), 222.0),
#  (116570, DateRange(datetime.date(2008, 10, 7), datetime.date(2008, 10, 15), '[)'), 134.0),
#  (116978, DateRange(datetime.date(2008, 10, 15), datetime.date(2008, 10, 23), '[)'), 95.0),
#  (117386, DateRange(datetime.date(2008, 10, 23), datetime.date(2008, 10, 31), '[)'), 52.0),
#  (117794, DateRange(datetime.date(2008, 10, 31), datetime.date(2008, 11, 8), '[)'), 79.0),
#  (118202, DateRange(datetime.date(2008, 11, 8), datetime.date(2008, 11, 16), '[)'), 6.0),
#  (118610, DateRange(datetime.date(2008, 11, 16), datetime.date(2008, 11, 24), '[)'), 4.0),
#  (119018, DateRange(datetime.date(2008, 11, 24), datetime.date(2008, 12, 2), '[)'), 9.0),
#  (119426, DateRange(datetime.date(2008, 12, 2), datetime.date(2008, 12, 10), '[)'), 0.0),
#  (119834, DateRange(datetime.date(2008, 12, 10), datetime.date(2008, 12, 18), '[)'), 0.0),
#  (120242, DateRange(datetime.date(2008, 12, 18), datetime.date(2008, 12, 26), '[)'), 0.0),
#  (120650, DateRange(datetime.date(2008, 12, 26), datetime.date(2009, 1, 1), '[)'), 0.0),
#  (121058, DateRange(datetime.date(2009, 1, 1), datetime.date(2009, 1, 9), '[)'), 0.0),
#  (121466, DateRange(datetime.date(2009, 1, 9), datetime.date(2009, 1, 17), '[)'), 0.0),
#  (121874, DateRange(datetime.date(2009, 1, 17), datetime.date(2009, 1, 25), '[)'), 0.0),
#  (122282, DateRange(datetime.date(2009, 1, 25), datetime.date(2009, 2, 2), '[)'), 0.0),
#  (122690, DateRange(datetime.date(2009, 2, 2), datetime.date(2009, 2, 10), '[)'), 0.0),
#  (123098, DateRange(datetime.date(2009, 2, 10), datetime.date(2009, 2, 18), '[)'), 7.0),
#  (123506, DateRange(datetime.date(2009, 2, 18), datetime.date(2009, 2, 26), '[)'), 5.0),
#  (123914, DateRange(datetime.date(2009, 2, 26), datetime.date(2009, 3, 6), '[)'), 5.0),
#  (124322, DateRange(datetime.date(2009, 3, 6), datetime.date(2009, 3, 14), '[)'), 8.0),
#  (124730, DateRange(datetime.date(2009, 3, 14), datetime.date(2009, 3, 22), '[)'), 37.0),
#  (125138, DateRange(datetime.date(2009, 3, 22), datetime.date(2009, 3, 30), '[)'), 29.0),
#  (125546, DateRange(datetime.date(2009, 3, 30), datetime.date(2009, 4, 7), '[)'), 15.0),
#  (125954, DateRange(datetime.date(2009, 4, 7), datetime.date(2009, 4, 15), '[)'), 31.0),
#  (126362, DateRange(datetime.date(2009, 4, 15), datetime.date(2009, 4, 23), '[)'), 56.0),
#  (126770, DateRange(datetime.date(2009, 4, 23), datetime.date(2009, 5, 1), '[)'), 31.0),
#  (127178, DateRange(datetime.date(2009, 5, 1), datetime.date(2009, 5, 9), '[)'), 132.0),
#  (127586, DateRange(datetime.date(2009, 5, 9), datetime.date(2009, 5, 17), '[)'), 141.0),
#  (127994, DateRange(datetime.date(2009, 5, 17), datetime.date(2009, 5, 25), '[)'), 210.0),
#  (128402, DateRange(datetime.date(2009, 5, 25), datetime.date(2009, 6, 2), '[)'), 212.0),
#  (128810, DateRange(datetime.date(2009, 6, 2), datetime.date(2009, 6, 10), '[)'), 204.0),
#  (129218, DateRange(datetime.date(2009, 6, 10), datetime.date(2009, 6, 18), '[)'), 252.0),
#  (129626, DateRange(datetime.date(2009, 6, 18), datetime.date(2009, 6, 26), '[)'), 419.0),
#  (130034, DateRange(datetime.date(2009, 6, 26), datetime.date(2009, 7, 4), '[)'), 509.0),
#  (130442, DateRange(datetime.date(2009, 7, 4), datetime.date(2009, 7, 12), '[)'), 536.0),
#  (130850, DateRange(datetime.date(2009, 7, 12), datetime.date(2009, 7, 20), '[)'), 627.0),
#  (131258, DateRange(datetime.date(2009, 7, 20), datetime.date(2009, 7, 28), '[)'), 865.0),
#  (131666, DateRange(datetime.date(2009, 7, 28), datetime.date(2009, 8, 5), '[)'), 780.0),
#  (132074, DateRange(datetime.date(2009, 8, 5), datetime.date(2009, 8, 13), '[)'), 669.0),
#  (132482, DateRange(datetime.date(2009, 8, 13), datetime.date(2009, 8, 21), '[)'), 471.0),
#  (132890, DateRange(datetime.date(2009, 8, 21), datetime.date(2009, 8, 29), '[)'), 487.0),
#  (133298, DateRange(datetime.date(2009, 8, 29), datetime.date(2009, 9, 6), '[)'), 546.0),
#  (133706, DateRange(datetime.date(2009, 9, 6), datetime.date(2009, 9, 14), '[)'), 498.0),
#  (134114, DateRange(datetime.date(2009, 9, 14), datetime.date(2009, 9, 22), '[)'), 303.0),
#  (134522, DateRange(datetime.date(2009, 9, 22), datetime.date(2009, 9, 30), '[)'), 227.0),
#  (134930, DateRange(datetime.date(2009, 9, 30), datetime.date(2009, 10, 8), '[)'), 110.0),
#  (135338, DateRange(datetime.date(2009, 10, 8), datetime.date(2009, 10, 16), '[)'), 50.0),
#  (135746, DateRange(datetime.date(2009, 10, 16), datetime.date(2009, 10, 24), '[)'), 54.0),
#  (136154, DateRange(datetime.date(2009, 10, 24), datetime.date(2009, 11, 1), '[)'), 32.0),
#  (136562, DateRange(datetime.date(2009, 11, 1), datetime.date(2009, 11, 9), '[)'), 20.0),
#  (136970, DateRange(datetime.date(2009, 11, 9), datetime.date(2009, 11, 17), '[)'), 29.0),
#  (137378, DateRange(datetime.date(2009, 11, 17), datetime.date(2009, 11, 25), '[)'), 13.0),
#  (137786, DateRange(datetime.date(2009, 11, 25), datetime.date(2009, 12, 3), '[)'), 19.0),
#  (138194, DateRange(datetime.date(2009, 12, 3), datetime.date(2009, 12, 11), '[)'), 0.0),
#  (138602, DateRange(datetime.date(2009, 12, 11), datetime.date(2009, 12, 19), '[)'), 0.0),
#  (139010, DateRange(datetime.date(2009, 12, 19), datetime.date(2009, 12, 27), '[)'), 0.0),
#  (139418, DateRange(datetime.date(2009, 12, 27), datetime.date(2010, 1, 1), '[)'), 0.0),
#  (139826, DateRange(datetime.date(2010, 1, 1), datetime.date(2010, 1, 9), '[)'), 0.0),
#  (140234, DateRange(datetime.date(2010, 1, 9), datetime.date(2010, 1, 17), '[)'), 0.0),
#  (140642, DateRange(datetime.date(2010, 1, 17), datetime.date(2010, 1, 25), '[)'), 0.0),
#  (141050, DateRange(datetime.date(2010, 1, 25), datetime.date(2010, 2, 2), '[)'), 0.0),
#  (141458, DateRange(datetime.date(2010, 2, 2), datetime.date(2010, 2, 10), '[)'), 0.0),
#  (141866, DateRange(datetime.date(2010, 2, 10), datetime.date(2010, 2, 18), '[)'), 0.0),
#  (142274, DateRange(datetime.date(2010, 2, 18), datetime.date(2010, 2, 26), '[)'), 0.0),
#  (142682, DateRange(datetime.date(2010, 2, 26), datetime.date(2010, 3, 6), '[)'), 0.0),
#  (143090, DateRange(datetime.date(2010, 3, 6), datetime.date(2010, 3, 14), '[)'), 0.0),
#  (143498, DateRange(datetime.date(2010, 3, 14), datetime.date(2010, 3, 22), '[)'), 28.0),
#  (143906, DateRange(datetime.date(2010, 3, 22), datetime.date(2010, 3, 30), '[)'), 37.0),
#  (144314, DateRange(datetime.date(2010, 3, 30), datetime.date(2010, 4, 7), '[)'), 60.0),
#  (144722, DateRange(datetime.date(2010, 4, 7), datetime.date(2010, 4, 15), '[)'), 169.0),
#  (145130, DateRange(datetime.date(2010, 4, 15), datetime.date(2010, 4, 23), '[)'), 125.0),
#  (145538, DateRange(datetime.date(2010, 4, 23), datetime.date(2010, 5, 1), '[)'), 135.0),
#  (145946, DateRange(datetime.date(2010, 5, 1), datetime.date(2010, 5, 9), '[)'), 185.0),
#  (146354, DateRange(datetime.date(2010, 5, 9), datetime.date(2010, 5, 17), '[)'), 98.0),
#  (146762, DateRange(datetime.date(2010, 5, 17), datetime.date(2010, 5, 25), '[)'), 109.0),
#  (147170, DateRange(datetime.date(2010, 5, 25), datetime.date(2010, 6, 2), '[)'), 239.0),
#  (147578, DateRange(datetime.date(2010, 6, 2), datetime.date(2010, 6, 10), '[)'), 219.0),
#  (147986, DateRange(datetime.date(2010, 6, 10), datetime.date(2010, 6, 18), '[)'), 348.0),
#  (148394, DateRange(datetime.date(2010, 6, 18), datetime.date(2010, 6, 26), '[)'), 504.0),
#  (148802, DateRange(datetime.date(2010, 6, 26), datetime.date(2010, 7, 4), '[)'), 654.0),
#  (149210, DateRange(datetime.date(2010, 7, 4), datetime.date(2010, 7, 12), '[)'), 555.0),
#  (149618, DateRange(datetime.date(2010, 7, 12), datetime.date(2010, 7, 20), '[)'), 714.0),
#  (150026, DateRange(datetime.date(2010, 7, 20), datetime.date(2010, 7, 28), '[)'), 774.0),
#  (150434, DateRange(datetime.date(2010, 7, 28), datetime.date(2010, 8, 5), '[)'), 709.0),
#  (150842, DateRange(datetime.date(2010, 8, 5), datetime.date(2010, 8, 13), '[)'), 770.0),
#  (151250, DateRange(datetime.date(2010, 8, 13), datetime.date(2010, 8, 21), '[)'), 728.0),
#  (151658, DateRange(datetime.date(2010, 8, 21), datetime.date(2010, 8, 29), '[)'), 769.0),
#  (152066, DateRange(datetime.date(2010, 8, 29), datetime.date(2010, 9, 6), '[)'), 575.0),
#  (152474, DateRange(datetime.date(2010, 9, 6), datetime.date(2010, 9, 14), '[)'), 484.0),
#  (152882, DateRange(datetime.date(2010, 9, 14), datetime.date(2010, 9, 22), '[)'), 221.0),
#  (153290, DateRange(datetime.date(2010, 9, 22), datetime.date(2010, 9, 30), '[)'), 133.0),
#  (153698, DateRange(datetime.date(2010, 9, 30), datetime.date(2010, 10, 8), '[)'), 108.0),
#  (154106, DateRange(datetime.date(2010, 10, 8), datetime.date(2010, 10, 16), '[)'), 123.0),
#  (154514, DateRange(datetime.date(2010, 10, 16), datetime.date(2010, 10, 24), '[)'), 63.0),
#  (154922, DateRange(datetime.date(2010, 10, 24), datetime.date(2010, 11, 1), '[)'), 65.0),
#  (155330, DateRange(datetime.date(2010, 11, 1), datetime.date(2010, 11, 9), '[)'), 39.0),
#  (155738, DateRange(datetime.date(2010, 11, 9), datetime.date(2010, 11, 17), '[)'), 28.0),
#  (156146, DateRange(datetime.date(2010, 11, 17), datetime.date(2010, 11, 25), '[)'), 4.0),
#  (156554, DateRange(datetime.date(2010, 11, 25), datetime.date(2010, 12, 3), '[)'), 1.0),
#  (156962, DateRange(datetime.date(2010, 12, 3), datetime.date(2010, 12, 11), '[)'), 0.0),
#  (157370, DateRange(datetime.date(2010, 12, 11), datetime.date(2010, 12, 19), '[)'), 0.0),
#  (157778, DateRange(datetime.date(2010, 12, 19), datetime.date(2010, 12, 27), '[)'), 0.0),
#  (158186, DateRange(datetime.date(2010, 12, 27), datetime.date(2011, 1, 1), '[)'), 0.0),
#  (158594, DateRange(datetime.date(2011, 1, 1), datetime.date(2011, 1, 9), '[)'), 0.0),
#  (159002, DateRange(datetime.date(2011, 1, 9), datetime.date(2011, 1, 17), '[)'), 0.0),
#  (159410, DateRange(datetime.date(2011, 1, 17), datetime.date(2011, 1, 25), '[)'), 0.0),
#  (159818, DateRange(datetime.date(2011, 1, 25), datetime.date(2011, 2, 2), '[)'), 0.0),
#  (160226, DateRange(datetime.date(2011, 2, 2), datetime.date(2011, 2, 10), '[)'), 0.0),
#  (160634, DateRange(datetime.date(2011, 2, 10), datetime.date(2011, 2, 18), '[)'), 9.0),
#  (161042, DateRange(datetime.date(2011, 2, 18), datetime.date(2011, 2, 26), '[)'), 5.0),
#  (161450, DateRange(datetime.date(2011, 2, 26), datetime.date(2011, 3, 6), '[)'), 5.0),
#  (161858, DateRange(datetime.date(2011, 3, 6), datetime.date(2011, 3, 14), '[)'), 8.0),
#  (162266, DateRange(datetime.date(2011, 3, 14), datetime.date(2011, 3, 22), '[)'), 25.0),
#  (162674, DateRange(datetime.date(2011, 3, 22), datetime.date(2011, 3, 30), '[)'), 17.0),
#  (163082, DateRange(datetime.date(2011, 3, 30), datetime.date(2011, 4, 7), '[)'), 49.0),
#  (163490, DateRange(datetime.date(2011, 4, 7), datetime.date(2011, 4, 15), '[)'), 83.0),
#  (163898, DateRange(datetime.date(2011, 4, 15), datetime.date(2011, 4, 23), '[)'), 13.0),
#  (164306, DateRange(datetime.date(2011, 4, 23), datetime.date(2011, 5, 1), '[)'), 56.0),
#  (164714, DateRange(datetime.date(2011, 5, 1), datetime.date(2011, 5, 9), '[)'), 90.0),
#  (165122, DateRange(datetime.date(2011, 5, 9), datetime.date(2011, 5, 17), '[)'), 88.0),
#  (165530, DateRange(datetime.date(2011, 5, 17), datetime.date(2011, 5, 25), '[)'), 164.0),
#  (165938, DateRange(datetime.date(2011, 5, 25), datetime.date(2011, 6, 2), '[)'), 203.0),
#  (166346, DateRange(datetime.date(2011, 6, 2), datetime.date(2011, 6, 10), '[)'), 248.0),
#  (166754, DateRange(datetime.date(2011, 6, 10), datetime.date(2011, 6, 18), '[)'), 258.0),
#  (167162, DateRange(datetime.date(2011, 6, 18), datetime.date(2011, 6, 26), '[)'), 193.0),
#  (167570, DateRange(datetime.date(2011, 6, 26), datetime.date(2011, 7, 4), '[)'), 535.0),
#  (167978, DateRange(datetime.date(2011, 7, 4), datetime.date(2011, 7, 12), '[)'), 648.0),
#  (168386, DateRange(datetime.date(2011, 7, 12), datetime.date(2011, 7, 20), '[)'), 685.0),
#  (168794, DateRange(datetime.date(2011, 7, 20), datetime.date(2011, 7, 28), '[)'), 589.0),
#  (169202, DateRange(datetime.date(2011, 7, 28), datetime.date(2011, 8, 5), '[)'), 430.0),
#  (169610, DateRange(datetime.date(2011, 8, 5), datetime.date(2011, 8, 13), '[)'), 668.0),
#  (170018, DateRange(datetime.date(2011, 8, 13), datetime.date(2011, 8, 21), '[)'), 656.0),
#  (170426, DateRange(datetime.date(2011, 8, 21), datetime.date(2011, 8, 29), '[)'), 546.0),
#  (170834, DateRange(datetime.date(2011, 8, 29), datetime.date(2011, 9, 6), '[)'), 475.0),
#  (171242, DateRange(datetime.date(2011, 9, 6), datetime.date(2011, 9, 14), '[)'), 555.0),
#  (171650, DateRange(datetime.date(2011, 9, 14), datetime.date(2011, 9, 22), '[)'), 291.0),
#  (172058, DateRange(datetime.date(2011, 9, 22), datetime.date(2011, 9, 30), '[)'), 127.0),
#  (172466, DateRange(datetime.date(2011, 9, 30), datetime.date(2011, 10, 8), '[)'), 135.0),
#  (172874, DateRange(datetime.date(2011, 10, 8), datetime.date(2011, 10, 16), '[)'), 117.0),
#  (173282, DateRange(datetime.date(2011, 10, 16), datetime.date(2011, 10, 24), '[)'), 63.0),
#  (173690, DateRange(datetime.date(2011, 10, 24), datetime.date(2011, 11, 1), '[)'), 50.0),
#  (174098, DateRange(datetime.date(2011, 11, 1), datetime.date(2011, 11, 9), '[)'), 20.0),
#  (174506, DateRange(datetime.date(2011, 11, 9), datetime.date(2011, 11, 17), '[)'), 25.0),
#  (174914, DateRange(datetime.date(2011, 11, 17), datetime.date(2011, 11, 25), '[)'), 7.0),
#  (175322, DateRange(datetime.date(2011, 11, 25), datetime.date(2011, 12, 3), '[)'), 6.0),
#  (175730, DateRange(datetime.date(2011, 12, 3), datetime.date(2011, 12, 11), '[)'), 0.0),
#  (176138, DateRange(datetime.date(2011, 12, 11), datetime.date(2011, 12, 19), '[)'), 6.0),
#  (176546, DateRange(datetime.date(2011, 12, 19), datetime.date(2011, 12, 27), '[)'), 6.0),
#  (176954, DateRange(datetime.date(2011, 12, 27), datetime.date(2012, 1, 1), '[)'), 5.0),
#  (177362, DateRange(datetime.date(2012, 1, 1), datetime.date(2012, 1, 9), '[)'), 6.0),
#  (177770, DateRange(datetime.date(2012, 1, 9), datetime.date(2012, 1, 17), '[)'), 5.0),
#  (178178, DateRange(datetime.date(2012, 1, 17), datetime.date(2012, 1, 25), '[)'), 0.0),
#  (178586, DateRange(datetime.date(2012, 1, 25), datetime.date(2012, 2, 2), '[)'), 4.0),
#  (178994, DateRange(datetime.date(2012, 2, 2), datetime.date(2012, 2, 10), '[)'), 6.0),
#  (179402, DateRange(datetime.date(2012, 2, 10), datetime.date(2012, 2, 18), '[)'), 6.0),
#  (179810, DateRange(datetime.date(2012, 2, 18), datetime.date(2012, 2, 26), '[)'), 10.0),
#  (180218, DateRange(datetime.date(2012, 2, 26), datetime.date(2012, 3, 5), '[)'), 7.0),
#  (180626, DateRange(datetime.date(2012, 3, 5), datetime.date(2012, 3, 13), '[)'), 21.0),
#  (181034, DateRange(datetime.date(2012, 3, 13), datetime.date(2012, 3, 21), '[)'), 71.0),
#  (181442, DateRange(datetime.date(2012, 3, 21), datetime.date(2012, 3, 29), '[)'), 76.0),
#  (181850, DateRange(datetime.date(2012, 3, 29), datetime.date(2012, 4, 6), '[)'), 72.0),
#  (182258, DateRange(datetime.date(2012, 4, 6), datetime.date(2012, 4, 14), '[)'), 45.0),
#  (182666, DateRange(datetime.date(2012, 4, 14), datetime.date(2012, 4, 22), '[)'), 80.0),
#  (183074, DateRange(datetime.date(2012, 4, 22), datetime.date(2012, 4, 30), '[)'), 86.0),
#  (183482, DateRange(datetime.date(2012, 4, 30), datetime.date(2012, 5, 8), '[)'), 169.0),
#  (183890, DateRange(datetime.date(2012, 5, 8), datetime.date(2012, 5, 16), '[)'), 202.0),
#  (184298, DateRange(datetime.date(2012, 5, 16), datetime.date(2012, 5, 24), '[)'), 177.0),
#  (184706, DateRange(datetime.date(2012, 5, 24), datetime.date(2012, 6, 1), '[)'), 132.0),
#  (185114, DateRange(datetime.date(2012, 6, 1), datetime.date(2012, 6, 9), '[)'), 222.0),
#  (185522, DateRange(datetime.date(2012, 6, 9), datetime.date(2012, 6, 17), '[)'), 301.0),
#  (185930, DateRange(datetime.date(2012, 6, 17), datetime.date(2012, 6, 25), '[)'), 445.0),
#  (186338, DateRange(datetime.date(2012, 6, 25), datetime.date(2012, 7, 3), '[)'), 564.0),
#  (186746, DateRange(datetime.date(2012, 7, 3), datetime.date(2012, 7, 11), '[)'), 555.0),
#  (187154, DateRange(datetime.date(2012, 7, 11), datetime.date(2012, 7, 19), '[)'), 443.0),
#  (187562, DateRange(datetime.date(2012, 7, 19), datetime.date(2012, 7, 27), '[)'), 379.0),
#  (187970, DateRange(datetime.date(2012, 7, 27), datetime.date(2012, 8, 4), '[)'), 426.0),
#  (188378, DateRange(datetime.date(2012, 8, 4), datetime.date(2012, 8, 12), '[)'), 495.0),
#  (188786, DateRange(datetime.date(2012, 8, 12), datetime.date(2012, 8, 20), '[)'), 452.0),
#  (189194, DateRange(datetime.date(2012, 8, 20), datetime.date(2012, 8, 28), '[)'), 355.0),
#  (189602, DateRange(datetime.date(2012, 8, 28), datetime.date(2012, 9, 5), '[)'), 272.0),
#  (190010, DateRange(datetime.date(2012, 9, 5), datetime.date(2012, 9, 13), '[)'), 269.0),
#  (190418, DateRange(datetime.date(2012, 9, 13), datetime.date(2012, 9, 21), '[)'), 196.0),
#  (190826, DateRange(datetime.date(2012, 9, 21), datetime.date(2012, 9, 29), '[)'), 134.0),
#  (191234, DateRange(datetime.date(2012, 9, 29), datetime.date(2012, 10, 7), '[)'), 93.0),
#  (191642, DateRange(datetime.date(2012, 10, 7), datetime.date(2012, 10, 15), '[)'), 47.0),
#  (192050, DateRange(datetime.date(2012, 10, 15), datetime.date(2012, 10, 23), '[)'), 26.0),
#  (192458, DateRange(datetime.date(2012, 10, 23), datetime.date(2012, 10, 31), '[)'), 20.0),
#  (192866, DateRange(datetime.date(2012, 10, 31), datetime.date(2012, 11, 8), '[)'), 16.0),
#  (193274, DateRange(datetime.date(2012, 11, 8), datetime.date(2012, 11, 16), '[)'), 12.0),
#  (193682, DateRange(datetime.date(2012, 11, 16), datetime.date(2012, 11, 24), '[)'), 25.0),
#  (194090, DateRange(datetime.date(2012, 11, 24), datetime.date(2012, 12, 2), '[)'), 3.0),
#  (194498, DateRange(datetime.date(2012, 12, 2), datetime.date(2012, 12, 10), '[)'), 9.0),
#  (194906, DateRange(datetime.date(2012, 12, 10), datetime.date(2012, 12, 18), '[)'), 5.0),
#  (195314, DateRange(datetime.date(2012, 12, 18), datetime.date(2012, 12, 26), '[)'), 0.0),
#  (195722, DateRange(datetime.date(2012, 12, 26), datetime.date(2013, 1, 1), '[)'), 0.0),
#  (196130, DateRange(datetime.date(2013, 1, 1), datetime.date(2013, 1, 9), '[)'), 0.0),
#  (196538, DateRange(datetime.date(2013, 1, 9), datetime.date(2013, 1, 17), '[)'), 0.0),
#  (196946, DateRange(datetime.date(2013, 1, 17), datetime.date(2013, 1, 25), '[)'), 2.0),
#  (197354, DateRange(datetime.date(2013, 1, 25), datetime.date(2013, 2, 2), '[)'), 2.0),
#  (197762, DateRange(datetime.date(2013, 2, 2), datetime.date(2013, 2, 10), '[)'), 1.0),
#  (198170, DateRange(datetime.date(2013, 2, 10), datetime.date(2013, 2, 18), '[)'), 4.0),
#  (198578, DateRange(datetime.date(2013, 2, 18), datetime.date(2013, 2, 26), '[)'), 2.0),
#  (198986, DateRange(datetime.date(2013, 2, 26), datetime.date(2013, 3, 6), '[)'), 0.0),
#  (199394, DateRange(datetime.date(2013, 3, 6), datetime.date(2013, 3, 14), '[)'), 0.0),
#  (199802, DateRange(datetime.date(2013, 3, 14), datetime.date(2013, 3, 22), '[)'), 0.0),
#  (200210, DateRange(datetime.date(2013, 3, 22), datetime.date(2013, 3, 30), '[)'), 11.0),
#  (200618, DateRange(datetime.date(2013, 3, 30), datetime.date(2013, 4, 7), '[)'), 16.0),
#  (201026, DateRange(datetime.date(2013, 4, 7), datetime.date(2013, 4, 15), '[)'), 14.0),
#  (201434, DateRange(datetime.date(2013, 4, 15), datetime.date(2013, 4, 23), '[)'), 29.0),
#  (201842, DateRange(datetime.date(2013, 4, 23), datetime.date(2013, 5, 1), '[)'), 63.0),
#  (202250, DateRange(datetime.date(2013, 5, 1), datetime.date(2013, 5, 9), '[)'), 49.0),
#  (202658, DateRange(datetime.date(2013, 5, 9), datetime.date(2013, 5, 17), '[)'), 189.0),
#  (203066, DateRange(datetime.date(2013, 5, 17), datetime.date(2013, 5, 25), '[)'), 219.0),
#  (203474, DateRange(datetime.date(2013, 5, 25), datetime.date(2013, 6, 2), '[)'), 132.0),
#  (203882, DateRange(datetime.date(2013, 6, 2), datetime.date(2013, 6, 10), '[)'), 162.0),
#  (204290, DateRange(datetime.date(2013, 6, 10), datetime.date(2013, 6, 18), '[)'), 226.0),
#  (204698, DateRange(datetime.date(2013, 6, 18), datetime.date(2013, 6, 26), '[)'), 201.0),
#  (205106, DateRange(datetime.date(2013, 6, 26), datetime.date(2013, 7, 4), '[)'), 464.0),
#  (205514, DateRange(datetime.date(2013, 7, 4), datetime.date(2013, 7, 12), '[)'), 629.0),
#  (205922, DateRange(datetime.date(2013, 7, 12), datetime.date(2013, 7, 20), '[)'), 549.0),
#  (206330, DateRange(datetime.date(2013, 7, 20), datetime.date(2013, 7, 28), '[)'), 262.0),
#  (206738, DateRange(datetime.date(2013, 7, 28), datetime.date(2013, 8, 5), '[)'), 622.0),
#  (207146, DateRange(datetime.date(2013, 8, 5), datetime.date(2013, 8, 13), '[)'), 649.0),
#  (207554, DateRange(datetime.date(2013, 8, 13), datetime.date(2013, 8, 21), '[)'), 776.0),
#  (207962, DateRange(datetime.date(2013, 8, 21), datetime.date(2013, 8, 29), '[)'), 706.0),
#  (208370, DateRange(datetime.date(2013, 8, 29), datetime.date(2013, 9, 6), '[)'), 640.0),
#  (208778, DateRange(datetime.date(2013, 9, 6), datetime.date(2013, 9, 14), '[)'), 510.0),
#  (209186, DateRange(datetime.date(2013, 9, 14), datetime.date(2013, 9, 22), '[)'), 387.0),
#  (209594, DateRange(datetime.date(2013, 9, 22), datetime.date(2013, 9, 30), '[)'), 301.0),
#  (210002, DateRange(datetime.date(2013, 9, 30), datetime.date(2013, 10, 8), '[)'), 147.0),
#  (210410, DateRange(datetime.date(2013, 10, 8), datetime.date(2013, 10, 16), '[)'), 166.0),
#  (210818, DateRange(datetime.date(2013, 10, 16), datetime.date(2013, 10, 24), '[)'), 51.0),
#  (211226, DateRange(datetime.date(2013, 10, 24), datetime.date(2013, 11, 1), '[)'), 27.0),
#  (211634, DateRange(datetime.date(2013, 11, 1), datetime.date(2013, 11, 9), '[)'), 21.0),
#  (212042, DateRange(datetime.date(2013, 11, 9), datetime.date(2013, 11, 17), '[)'), 9.0),
#  (212450, DateRange(datetime.date(2013, 11, 17), datetime.date(2013, 11, 25), '[)'), 9.0),
#  (212858, DateRange(datetime.date(2013, 11, 25), datetime.date(2013, 12, 3), '[)'), 5.0),
#  (213266, DateRange(datetime.date(2013, 12, 3), datetime.date(2013, 12, 11), '[)'), 1.0),
#  (213674, DateRange(datetime.date(2013, 12, 11), datetime.date(2013, 12, 19), '[)'), 0.0),
#  (214082, DateRange(datetime.date(2013, 12, 19), datetime.date(2013, 12, 27), '[)'), 0.0),
#  (214490, DateRange(datetime.date(2013, 12, 27), datetime.date(2014, 1, 1), '[)'), 0.0),
#  (214898, DateRange(datetime.date(2014, 1, 1), datetime.date(2014, 1, 9), '[)'), 0.0),
#  (215306, DateRange(datetime.date(2014, 1, 9), datetime.date(2014, 1, 17), '[)'), 0.0),
#  (215714, DateRange(datetime.date(2014, 1, 17), datetime.date(2014, 1, 25), '[)'), 0.0),
#  (216122, DateRange(datetime.date(2014, 1, 25), datetime.date(2014, 2, 2), '[)'), 0.0),
#  (216530, DateRange(datetime.date(2014, 2, 2), datetime.date(2014, 2, 10), '[)'), 0.0),
#  (216938, DateRange(datetime.date(2014, 2, 10), datetime.date(2014, 2, 18), '[)'), 0.0),
#  (217346, DateRange(datetime.date(2014, 2, 18), datetime.date(2014, 2, 26), '[)'), 0.0),
#  (217754, DateRange(datetime.date(2014, 2, 26), datetime.date(2014, 3, 6), '[)'), 0.0),
#  (218162, DateRange(datetime.date(2014, 3, 6), datetime.date(2014, 3, 14), '[)'), 5.0),
#  (218570, DateRange(datetime.date(2014, 3, 14), datetime.date(2014, 3, 22), '[)'), 18.0),
#  (218978, DateRange(datetime.date(2014, 3, 22), datetime.date(2014, 3, 30), '[)'), 10.0),
#  (219386, DateRange(datetime.date(2014, 3, 30), datetime.date(2014, 4, 7), '[)'), 23.0),
#  (219794, DateRange(datetime.date(2014, 4, 7), datetime.date(2014, 4, 15), '[)'), 42.0),
#  (220202, DateRange(datetime.date(2014, 4, 15), datetime.date(2014, 4, 23), '[)'), 51.0),
#  (220610, DateRange(datetime.date(2014, 4, 23), datetime.date(2014, 5, 1), '[)'), 37.0),
#  (221018, DateRange(datetime.date(2014, 5, 1), datetime.date(2014, 5, 9), '[)'), 99.0),
#  (221426, DateRange(datetime.date(2014, 5, 9), datetime.date(2014, 5, 17), '[)'), 10.0),
#  (221834, DateRange(datetime.date(2014, 5, 17), datetime.date(2014, 5, 25), '[)'), 169.0),
#  (222242, DateRange(datetime.date(2014, 5, 25), datetime.date(2014, 6, 2), '[)'), 127.0),
#  (222650, DateRange(datetime.date(2014, 6, 2), datetime.date(2014, 6, 10), '[)'), 258.0),
#  (223058, DateRange(datetime.date(2014, 6, 10), datetime.date(2014, 6, 18), '[)'), 246.0),
#  (223466, DateRange(datetime.date(2014, 6, 18), datetime.date(2014, 6, 26), '[)'), 312.0),
#  (223874, DateRange(datetime.date(2014, 6, 26), datetime.date(2014, 7, 4), '[)'), 527.0),
#  (224282, DateRange(datetime.date(2014, 7, 4), datetime.date(2014, 7, 12), '[)'), 403.0),
#  (224690, DateRange(datetime.date(2014, 7, 12), datetime.date(2014, 7, 20), '[)'), 652.0),
#  (225098, DateRange(datetime.date(2014, 7, 20), datetime.date(2014, 7, 28), '[)'), 761.0),
#  (225506, DateRange(datetime.date(2014, 7, 28), datetime.date(2014, 8, 5), '[)'), 613.0),
#  (225914, DateRange(datetime.date(2014, 8, 5), datetime.date(2014, 8, 13), '[)'), 640.0),
#  (226322, DateRange(datetime.date(2014, 8, 13), datetime.date(2014, 8, 21), '[)'), 288.0),
#  (226730, DateRange(datetime.date(2014, 8, 21), datetime.date(2014, 8, 29), '[)'), 608.0),
#  (227138, DateRange(datetime.date(2014, 8, 29), datetime.date(2014, 9, 6), '[)'), 593.0),
#  (227546, DateRange(datetime.date(2014, 9, 6), datetime.date(2014, 9, 14), '[)'), 424.0),
#  (227954, DateRange(datetime.date(2014, 9, 14), datetime.date(2014, 9, 22), '[)'), 387.0),
#  (228362, DateRange(datetime.date(2014, 9, 22), datetime.date(2014, 9, 30), '[)'), 222.0),
#  (228770, DateRange(datetime.date(2014, 9, 30), datetime.date(2014, 10, 8), '[)'), 101.0),
#  (229178, DateRange(datetime.date(2014, 10, 8), datetime.date(2014, 10, 16), '[)'), 85.0),
#  (229586, DateRange(datetime.date(2014, 10, 16), datetime.date(2014, 10, 24), '[)'), 97.0),
#  (229994, DateRange(datetime.date(2014, 10, 24), datetime.date(2014, 11, 1), '[)'), 27.0),
#  (230402, DateRange(datetime.date(2014, 11, 1), datetime.date(2014, 11, 9), '[)'), 30.0),
#  (230810, DateRange(datetime.date(2014, 11, 9), datetime.date(2014, 11, 17), '[)'), 3.0),
#  (231218, DateRange(datetime.date(2014, 11, 17), datetime.date(2014, 11, 25), '[)'), 5.0),
#  (231626, DateRange(datetime.date(2014, 11, 25), datetime.date(2014, 12, 3), '[)'), 1.0),
#  (232034, DateRange(datetime.date(2014, 12, 3), datetime.date(2014, 12, 11), '[)'), 3.0),
#  (232442, DateRange(datetime.date(2014, 12, 11), datetime.date(2014, 12, 19), '[)'), 4.0),
#  (232850, DateRange(datetime.date(2014, 12, 19), datetime.date(2014, 12, 27), '[)'), 0.0),
#  (233258, DateRange(datetime.date(2014, 12, 27), datetime.date(2015, 1, 1), '[)'), 0.0),
#  (233666, DateRange(datetime.date(2015, 1, 1), datetime.date(2015, 1, 9), '[)'), 0.0),
#  (234074, DateRange(datetime.date(2015, 1, 9), datetime.date(2015, 1, 17), '[)'), 0.0),
#  (234482, DateRange(datetime.date(2015, 1, 17), datetime.date(2015, 1, 25), '[)'), 5.0),
#  (234890, DateRange(datetime.date(2015, 1, 25), datetime.date(2015, 2, 2), '[)'), 6.0),
#  (235298, DateRange(datetime.date(2015, 2, 2), datetime.date(2015, 2, 10), '[)'), 0.0),
#  (235706, DateRange(datetime.date(2015, 2, 10), datetime.date(2015, 2, 18), '[)'), 0.0),
#  (236114, DateRange(datetime.date(2015, 2, 18), datetime.date(2015, 2, 26), '[)'), 0.0),
#  (236522, DateRange(datetime.date(2015, 2, 26), datetime.date(2015, 3, 6), '[)'), 0.0),
#  (236930, DateRange(datetime.date(2015, 3, 6), datetime.date(2015, 3, 14), '[)'), 37.0),
#  (237338, DateRange(datetime.date(2015, 3, 14), datetime.date(2015, 3, 22), '[)'), 39.0),
#  (237746, DateRange(datetime.date(2015, 3, 22), datetime.date(2015, 3, 30), '[)'), 19.0),
#  (238154, DateRange(datetime.date(2015, 3, 30), datetime.date(2015, 4, 7), '[)'), 70.0),
#  (238562, DateRange(datetime.date(2015, 4, 7), datetime.date(2015, 4, 15), '[)'), 62.0),
#  (238970, DateRange(datetime.date(2015, 4, 15), datetime.date(2015, 4, 23), '[)'), 89.0),
#  (239378, DateRange(datetime.date(2015, 4, 23), datetime.date(2015, 5, 1), '[)'), 112.0),
#  (239786, DateRange(datetime.date(2015, 5, 1), datetime.date(2015, 5, 9), '[)'), 119.0),
#  (240194, DateRange(datetime.date(2015, 5, 9), datetime.date(2015, 5, 17), '[)'), 176.0),
#  (240602, DateRange(datetime.date(2015, 5, 17), datetime.date(2015, 5, 25), '[)'), 138.0),
#  (241010, DateRange(datetime.date(2015, 5, 25), datetime.date(2015, 6, 2), '[)'), 198.0),
#  (241418, DateRange(datetime.date(2015, 6, 2), datetime.date(2015, 6, 10), '[)'), 325.0),
#  (241826, DateRange(datetime.date(2015, 6, 10), datetime.date(2015, 6, 18), '[)'), 321.0),
#  (242234, DateRange(datetime.date(2015, 6, 18), datetime.date(2015, 6, 26), '[)'), 376.0),
#  (242642, DateRange(datetime.date(2015, 6, 26), datetime.date(2015, 7, 4), '[)'), 667.0),
#  (243050, DateRange(datetime.date(2015, 7, 4), datetime.date(2015, 7, 12), '[)'), 584.0),
#  (243458, DateRange(datetime.date(2015, 7, 12), datetime.date(2015, 7, 20), '[)'), 681.0),
#  (243866, DateRange(datetime.date(2015, 7, 20), datetime.date(2015, 7, 28), '[)'), 752.0),
#  (244274, DateRange(datetime.date(2015, 7, 28), datetime.date(2015, 8, 5), '[)'), 767.0),
#  (244682, DateRange(datetime.date(2015, 8, 5), datetime.date(2015, 8, 13), '[)'), 273.0),
#  (245090, DateRange(datetime.date(2015, 8, 13), datetime.date(2015, 8, 21), '[)'), 575.0),
#  (245498, DateRange(datetime.date(2015, 8, 21), datetime.date(2015, 8, 29), '[)'), 558.0),
#  (245906, DateRange(datetime.date(2015, 8, 29), datetime.date(2015, 9, 6), '[)'), 567.0),
#  (246314, DateRange(datetime.date(2015, 9, 6), datetime.date(2015, 9, 14), '[)'), 459.0),
#  (246722, DateRange(datetime.date(2015, 9, 14), datetime.date(2015, 9, 22), '[)'), 319.0),
#  (247130, DateRange(datetime.date(2015, 9, 22), datetime.date(2015, 9, 30), '[)'), 189.0),
#  (247538, DateRange(datetime.date(2015, 9, 30), datetime.date(2015, 10, 8), '[)'), 147.0),
#  (247946, DateRange(datetime.date(2015, 10, 8), datetime.date(2015, 10, 16), '[)'), 132.0),
#  (248354, DateRange(datetime.date(2015, 10, 16), datetime.date(2015, 10, 24), '[)'), 69.0),
#  (248762, DateRange(datetime.date(2015, 10, 24), datetime.date(2015, 11, 1), '[)'), 55.0),
#  (249170, DateRange(datetime.date(2015, 11, 1), datetime.date(2015, 11, 9), '[)'), 54.0),
#  (249578, DateRange(datetime.date(2015, 11, 9), datetime.date(2015, 11, 17), '[)'), 42.0),
#  (249986, DateRange(datetime.date(2015, 11, 17), datetime.date(2015, 11, 25), '[)'), 6.0),
#  (250394, DateRange(datetime.date(2015, 11, 25), datetime.date(2015, 12, 3), '[)'), 3.0),
#  (250802, DateRange(datetime.date(2016, 1, 1), datetime.date(2016, 1, 9), '[)'), 0.0),
#  (251210, DateRange(datetime.date(2016, 1, 9), datetime.date(2016, 1, 17), '[)'), 0.0),
#  (251618, DateRange(datetime.date(2016, 1, 17), datetime.date(2016, 1, 25), '[)'), 0.0),
#  (252026, DateRange(datetime.date(2016, 1, 25), datetime.date(2016, 2, 2), '[)'), 0.0),
#  (252434, DateRange(datetime.date(2016, 2, 2), datetime.date(2016, 2, 10), '[)'), 0.0),
#  (252842, DateRange(datetime.date(2016, 2, 10), datetime.date(2016, 2, 18), '[)'), 0.0),
#  (253250, DateRange(datetime.date(2016, 2, 18), datetime.date(2016, 2, 26), '[)'), 13.0),
#  (253658, DateRange(datetime.date(2016, 2, 26), datetime.date(2016, 3, 5), '[)'), 15.0),
#  (254066, DateRange(datetime.date(2016, 3, 5), datetime.date(2016, 3, 13), '[)'), 37.0),
#  (254474, DateRange(datetime.date(2016, 3, 13), datetime.date(2016, 3, 21), '[)'), 28.0),
#  (254882, DateRange(datetime.date(2016, 3, 21), datetime.date(2016, 3, 29), '[)'), 14.0),
#  (255290, DateRange(datetime.date(2016, 3, 29), datetime.date(2016, 4, 6), '[)'), 45.0),
#  (255698, DateRange(datetime.date(2016, 4, 6), datetime.date(2016, 4, 14), '[)'), 72.0),
#  (256106, DateRange(datetime.date(2016, 4, 14), datetime.date(2016, 4, 22), '[)'), 133.0),
#  (256514, DateRange(datetime.date(2016, 4, 22), datetime.date(2016, 4, 30), '[)'), 149.0),
#  (256922, DateRange(datetime.date(2016, 4, 30), datetime.date(2016, 5, 8), '[)'), 166.0),
#  (257330, DateRange(datetime.date(2016, 5, 8), datetime.date(2016, 5, 16), '[)'), 181.0),
#  (257738, DateRange(datetime.date(2016, 5, 16), datetime.date(2016, 5, 24), '[)'), 212.0),
#  (258146, DateRange(datetime.date(2016, 5, 24), datetime.date(2016, 6, 1), '[)'), 225.0),
#  (258554, DateRange(datetime.date(2016, 6, 1), datetime.date(2016, 6, 9), '[)'), 277.0),
#  (258962, DateRange(datetime.date(2016, 6, 9), datetime.date(2016, 6, 17), '[)'), 365.0),
#  (259370, DateRange(datetime.date(2016, 6, 17), datetime.date(2016, 6, 25), '[)'), 516.0),
#  (259778, DateRange(datetime.date(2016, 6, 25), datetime.date(2016, 7, 3), '[)'), 628.0),
#  (260186, DateRange(datetime.date(2016, 7, 3), datetime.date(2016, 7, 11), '[)'), 794.0),
#  (260594, DateRange(datetime.date(2016, 7, 11), datetime.date(2016, 7, 19), '[)'), 817.0),
#  (261002, DateRange(datetime.date(2016, 7, 19), datetime.date(2016, 7, 27), '[)'), 621.0),
#  (261410, DateRange(datetime.date(2016, 7, 27), datetime.date(2016, 8, 4), '[)'), 371.0),
#  (261818, DateRange(datetime.date(2016, 8, 4), datetime.date(2016, 8, 12), '[)'), 648.0),
#  (262226, DateRange(datetime.date(2016, 8, 12), datetime.date(2016, 8, 20), '[)'), 677.0),
#  (262634, DateRange(datetime.date(2016, 8, 20), datetime.date(2016, 8, 28), '[)'), 593.0),
#  (263042, DateRange(datetime.date(2016, 8, 28), datetime.date(2016, 9, 5), '[)'), 563.0),
#  (263450, DateRange(datetime.date(2016, 9, 5), datetime.date(2016, 9, 13), '[)'), 539.0),
#  (263858, DateRange(datetime.date(2016, 9, 13), datetime.date(2016, 9, 21), '[)'), 335.0),
#  (264266, DateRange(datetime.date(2016, 9, 21), datetime.date(2016, 9, 29), '[)'), 179.0),
#  (264674, DateRange(datetime.date(2016, 9, 29), datetime.date(2016, 10, 7), '[)'), 166.0),
#  (265082, DateRange(datetime.date(2016, 10, 7), datetime.date(2016, 10, 15), '[)'), 108.0),
#  (265490, DateRange(datetime.date(2016, 10, 15), datetime.date(2016, 10, 23), '[)'), 93.0),
#  (265898, DateRange(datetime.date(2016, 10, 23), datetime.date(2016, 10, 31), '[)'), 83.0),
#  (266306, DateRange(datetime.date(2016, 10, 31), datetime.date(2016, 11, 8), '[)'), 83.0),
#  (266714, DateRange(datetime.date(2016, 11, 8), datetime.date(2016, 11, 16), '[)'), 63.0),
#  (267122, DateRange(datetime.date(2016, 11, 16), datetime.date(2016, 11, 24), '[)'), 19.0),
#  (267530, DateRange(datetime.date(2016, 11, 24), datetime.date(2016, 12, 2), '[)'), 18.0),
#  (267938, DateRange(datetime.date(2016, 12, 2), datetime.date(2016, 12, 10), '[)'), 3.0),
#  (268346, DateRange(datetime.date(2016, 12, 10), datetime.date(2016, 12, 18), '[)'), 0.0),
#  (268754, DateRange(datetime.date(2016, 12, 18), datetime.date(2016, 12, 26), '[)'), 0.0),
#  (269162, DateRange(datetime.date(2016, 12, 26), datetime.date(2017, 1, 1), '[)'), 3.0)]

# %% [markdown]
# **NEXT STEP**
#
# Implement the query using a shapefile. That is the goal! This one here retrieves all the raster values withing a poligon in an array. From this we could to the stats externally, but we don't need it.

# %%
# %%time
# %%sql SELECT gid, acquisition_range, (st_dumpvalues(ST_Clip(rast,geom, true))).valarray
    FROM
    modis10v04.gpp , public.shape10v04
    WHERE st_intersects(rast,geom)
        AND acquisition_range && '[2015-01-01,2016-12-31]'::daterange 
        AND gid = 1 
    ORDER BY acquisition_range;

# %% [markdown]
# #### AND I FINALLY got what I WANT
#
# This query retrieves all the raster stats by polygon.

# %%
# %%time
# %%sql SELECT id, acquisition_range, (st_SummaryStats(ST_Clip(rast,1,geom, true))).mean as media,
    (st_SummaryStats(ST_Clip(rast,1,geom, true))).sum as soma,
    (st_SummaryStats(ST_Clip(rast,1,geom, true))).count as pixels,
    (st_SummaryStats(ST_Clip(rast,1,geom, true))).stddev as desvio,
    power((st_SummaryStats(ST_Clip(rast,1,geom, true))).stddev,2) as variancia,
    (st_SummaryStats(ST_Clip(rast,1,geom, true))).max as maximo
FROM modis10v04.gpp , public.shape10v04
WHERE st_intersects(rast,geom)
    AND acquisition_range && '[2005-01-01,2016-12-31]'::daterange 
    AND id = 1 
ORDER BY acquisition_range;

# %% [markdown]
# To put the result in a pandas dataframe we have to use single-line %sql statement, which make thinks a bit ugly, but it works!

# %%
result = %sql SELECT id, acquisition_range, (st_SummaryStats(ST_Clip(rast,1,geom, true))).mean as media FROM modis10v04.gpp , public.shape10v04 WHERE st_intersects(rast,geom) AND acquisition_range && '[2005-01-01,2016-12-31]'::daterange AND id =1 ORDER BY acquisition_range;

# %%
result.DataFrame()

# %%
result.csv(filename='work.csv')
